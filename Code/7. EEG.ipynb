# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import gc

import scipy.stats
from scipy.signal import welch
from scipy.stats import skew, kurtosis

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('./Cleaned_Train.csv')
train.head()
# Out:
#    eeg_id     spec_id     min     max  patient_id  seizure_vote  lpd_vote  \
# 0  568657   789577333     0.0    16.0       20654           0.0  0.000000
# 1  582999  1552638400     0.0    38.0       20230           0.0  0.857143
# 2  642382    14960202  1008.0  1032.0        5955           0.0  0.000000
# 3  751790   618728447   908.0   908.0       38549           0.0  0.000000
# 4  778705    52296320     0.0     0.0       40955           0.0  0.000000
#
#    gpd_vote  lrda_vote  grda_vote  other_vote target
# 0      0.25   0.000000   0.166667    0.583333  Other
# 1      0.00   0.071429   0.000000    0.071429    LPD
# 2      0.00   0.000000   0.000000    1.000000  Other
# 3      1.00   0.000000   0.000000    0.000000    GPD
# 4      0.00   0.000000   0.000000    1.000000  Other

# %%
# Function to load EEG data
def load_eeg_data(file_path):
    return pd.read_csv(file_path)

# Function to extract time domain features for PCA components
def extract_pca_time_domain_features(pca_data):
    return {
        'eeg_mean': np.mean(pca_data, axis=0).item(),
        'eeg_std_dev': np.std(pca_data, axis=0).item(),
        'eeg_skewness': skew(pca_data, axis=0).item(),
        'eeg_kurtosis': kurtosis(pca_data, axis=0).item()
    }

# %%
PATH = '../hms-harmful-brain-activity-classification/'
EEG_PATH = PATH + 'train_eegs/'

All_Spec_df = []
for i in range(len(train)):
    df_eeg = pd.read_parquet(EEG_PATH + str(train['eeg_id'][i]) + '.parquet')
    print(train['eeg_id'][i])
    df_eeg.fillna(df_eeg.mean(), inplace=True)
    scaler = StandardScaler()
    eeg_data_scaled = scaler.fit_transform(df_eeg.drop(['Unnamed: 0'], axis = 1, errors='ignore'))  # Drop non-EEG columns
    pca = PCA(n_components = 1)  # Retain 1 principal component for simplicity
    eeg_data_pca = pca.fit_transform(eeg_data_scaled)

    # Extract time-domain features from PCA components
    ok = extract_pca_time_domain_features(eeg_data_pca)
    new_item = {"eeg_id": train['eeg_id'][i]}
    ok = {**new_item, **ok}

    All_Spec_df.append(ok)
# Out:
# 568657
# 582999
# 642382
# 751790
# 778705
# 1629671
# 1895581
# 2061593
# 2078097
# 2366870
# 2482631
# 2521897
# 2918824
# 3108700
# 3625731
# 3851658
# 3907459
# 4431217
# 4454049
# 4559645
# 4904504
# 4969792
# 5168624
# 5423338
# 5424875
# 5485650
# 5586700
# 5710954
# 5993793
# 6259482
# 7278051
# 7585449
# 8027281
# 8071080
# 8922554
# 9240926
# 9418744
# 9859330
# 9980241
# 10249311
# 10343849
# 10386542
# 10466156
# 10617205
# 10687514
# 10859011
# 11127485
# 12197246
# 12298343
# 12422438
# 12784157
# 12830684
# 14548664
# 14609267
# 14623517
# 15073201
# 15238928
# 15271495
# 15981664
# 16002110
# 16114818
# 16178958
# 16982159
# 17295749
# 17311157
# 17662377
# 17714496
# 17875433
# 17987739
# 18169507
# 18263267
# 18802033
# 19239792
# 19529277
# 19740075
# 19780434
# 20299905
# 20697410
# 20915334
# 21054661
# 279482448
# 279662546
# 279789297
# 279879270
# 280395411
# 280564370
# 280580784
# 280792227
# 280907771
# 281083254
# 281236432
# 281309654
# 282027167
# 283242036
# 284987382
# 285463800
# 285851177
# 286010953
# 286066218
# 286263734
# 286516218
# 286915522
# 287171745
# 287229731
# 287655550
# 287838265
# 288107651
# 288179007
# 288385360
# 288656155
# 289210479
# 289371912
# 289435433
# 289773667
# 290007254
# 290851085
# 290927398
# 291346627
# 292306989
# 292399955
# 292472337
# 292601804
# 293154320
# 293155110
# 293230673
# 293236112
# 293554643
# 293658736
# 293706403
# 293981424
# 294287125
# 294836751
# 294889129
# 295069814
# 295123583
# 295560856
# 295741467
# 296327954
# 296456684
# 296706140
# 296989428
# 297047786
# 297091118
# 297360725
# 298029415
# 298296783
# 298615529
# 298760963
# 298831753
# 299056982
# 299109708
# 299439111
# 299540005
# 299571149
# 299817646
# 300031644
# 300252563
# 300476628
# 300733838
# 300834311
# 301132906
# 301329487
# 301537782
# 301692511
# 301841512
# 302266781
# 302313506
# 302337184
# 302577652
# 303508527
# 303721611
# 303777353
# 303793179
# 304029069
# 304123929
# 304202086
# 304631005
# 305400733
# 305507271
# 306022061
# 306394346
# 306718359
# 306981571
# 307063855
# 307761414
# 308034902
# 308227289
# 308550713
# 308562236
# 309342035
# 309597555
# 309647869
# 310418610
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 12
#      10 eeg_data_scaled = scaler.fit_transform(df_eeg.drop(['Unnamed: 0'], axis = 1, errors='ignore'))  # Drop non-EEG columns
#      11 pca = PCA(n_components = 1)  # Retain 1 principal component for simplicity
# ---> 12 eeg_data_pca = pca.fit_transform(eeg_data_scaled)
#      14 # Extract time-domain features from PCA components
#      15 ok = extract_pca_time_domain_features(eeg_data_pca)
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:460, in PCA.fit_transform(self, X, y)
#     437 @_fit_context(prefer_skip_nested_validation=True)
#     438 def fit_transform(self, X, y=None):
#     439     """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441     Parameters
#    (...)
#     458     C-ordered array, use 'np.ascontiguousarray'.
#     459     """
# --> 460     U, S, Vt = self._fit(X)
#     461     U = U[:, : self.n_components_]
#     463     if self.whiten:
#     464         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:512, in PCA._fit(self, X)
#     510     return self._fit_full(X, n_components)
#     511 elif self._fit_svd_solver in ["arpack", "randomized"]:
# --> 512     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/decomposition/_pca.py:616, in PCA._fit_truncated(self, X, n_components, svd_solver)
#     612     U, Vt = svd_flip(U[:, ::-1], Vt[::-1])
#     614 elif svd_solver == "randomized":
#     615     # sign flipping is done inside
# --> 616     U, S, Vt = randomized_svd(
#     617         X,
#     618         n_components=n_components,
#     619         n_oversamples=self.n_oversamples,
#     620         n_iter=self.iterated_power,
#     621         power_iteration_normalizer=self.power_iteration_normalizer,
#     622         flip_sign=True,
#     623         random_state=random_state,
#     624     )
#     626 self.n_samples_ = n_samples
#     627 self.components_ = Vt
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/utils/extmath.py:449, in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state, svd_lapack_driver)
#     445 if transpose:
#     446     # this implementation is a bit faster with smaller shape[1]
#     447     M = M.T
# --> 449 Q = randomized_range_finder(
#     450     M,
#     451     size=n_random,
#     452     n_iter=n_iter,
#     453     power_iteration_normalizer=power_iteration_normalizer,
#     454     random_state=random_state,
#     455 )
#     457 # project M to the (k + p) dimensional space using the basis vectors
#     458 B = safe_sparse_dot(Q.T, M)
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/utils/extmath.py:278, in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     276 elif power_iteration_normalizer == "LU":
#     277     Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
# --> 278     Q, _ = linalg.lu(safe_sparse_dot(A.T, Q), permute_l=True)
#     279 elif power_iteration_normalizer == "QR":
#     280     Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode="economic")
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/sklearn/utils/extmath.py:195, in safe_sparse_dot(a, b, dense_output)
#     191 else:
#     192     ret = a @ b
#     194 if (
# --> 195     sparse.issparse(a)
#     196     and sparse.issparse(b)
#     197     and dense_output
#     198     and hasattr(ret, "toarray")
#     199 ):
#     200     return ret.toarray()
#     201 return ret
#
# File ~/miniconda3/envs/Image_Captioning/lib/python3.11/site-packages/scipy/sparse/_base.py:1461, in issparse(x)
#    1456     pass
#    1458 sparray.__doc__ = _spbase.__doc__
# -> 1461 def issparse(x):
#    1462     """Is `x` of a sparse array type?
#    1463
#    1464     Parameters
#    (...)
#    1485     False
#    1486     """
#    1487     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
ok = pd.DataFrame(All_Spec_df)
ok.head()
# Out:
#    eeg_id      eeg_mean  eeg_std_dev  eeg_skewness  eeg_kurtosis
# 0  568657  1.849550e-08     3.277670      0.266662      2.634665
# 1  582999  4.855069e-08     3.418199     -0.095620      0.707420
# 2  642382  3.299198e-08     2.695353     -0.128804      0.071505

# %%
# ok.to_csv('ALL_EEG_DF.csv')
